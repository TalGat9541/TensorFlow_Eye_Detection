# %% [markdown]
# # 1. Install Dependencies and Setup

# %%
# !pip install labelme tensorflow tensorflow-gpu opencv-python matplotlib albumentations
# Out:
# Requirement already satisfied: labelme in c:\users\talga\anaconda3\lib\site-packages (5.1.1)
# Requirement already satisfied: tensorflow in c:\users\talga\anaconda3\lib\site-packages (2.11.0)
# Collecting tensorflow-gpu
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: opencv-python in c:\users\talga\anaconda3\lib\site-packages (4.7.0.68)
# Requirement already satisfied: matplotlib in c:\users\talga\anaconda3\lib\site-packages (3.5.2)
# Collecting albumentations
#   Downloading albumentations-1.3.0-py3-none-any.whl (123 kB)
#      ------------------------------------ 123.5/123.5 kB 453.2 kB/s eta 0:00:00
# Requirement already satisfied: imgviz>=0.11 in c:\users\talga\anaconda3\lib\site-packages (from labelme) (1.7.2)
# Requirement already satisfied: colorama in c:\users\talga\anaconda3\lib\site-packages (from labelme) (0.4.5)
# Requirement already satisfied: qtpy!=1.11.2 in c:\users\talga\anaconda3\lib\site-packages (from labelme) (2.2.0)
# Requirement already satisfied: termcolor in c:\users\talga\anaconda3\lib\site-packages (from labelme) (2.1.1)
# Requirement already satisfied: Pillow>=2.8 in c:\users\talga\anaconda3\lib\site-packages (from labelme) (9.2.0)
# Requirement already satisfied: numpy in c:\users\talga\anaconda3\lib\site-packages (from labelme) (1.21.5)
# Requirement already satisfied: natsort>=7.1.0 in c:\users\talga\anaconda3\lib\site-packages (from labelme) (8.2.0)
# Requirement already satisfied: PyYAML in c:\users\talga\anaconda3\lib\site-packages (from labelme) (6.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\talga\anaconda3\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: setuptools in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (63.4.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.28.0)
# Requirement already satisfied: packaging in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.3)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (14.0.6)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.51.1)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (22.12.6)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.7.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.14.1)
# Requirement already satisfied: python_version>"3.7" in c:\users\talga\anaconda3\lib\site-packages (from tensorflow-gpu) (0.0.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\talga\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\talga\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\talga\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\talga\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\talga\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: scikit-image>=0.16.1 in c:\users\talga\anaconda3\lib\site-packages (from albumentations) (0.19.2)
# Collecting qudida>=0.0.4
#   Downloading qudida-0.0.4-py3-none-any.whl (3.5 kB)
# Collecting opencv-python-headless>=4.1.1
#   Downloading opencv_python_headless-4.7.0.68-cp37-abi3-win_amd64.whl (38.1 MB)
#      ---------------------------------------- 38.1/38.1 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\talga\anaconda3\lib\site-packages (from albumentations) (1.9.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\talga\anaconda3\lib\site-packages (from qudida>=0.0.4->albumentations) (1.0.2)
# Requirement already satisfied: networkx>=2.2 in c:\users\talga\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations) (2.8.4)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\talga\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\talga\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations) (1.3.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\talga\anaconda3\lib\site-packages (from scikit-image>=0.16.1->albumentations) (2.19.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\talga\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\talga\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\talga\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (1.1.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\talga\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\talga\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\talga\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\talga\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.15.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\talga\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\talga\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\talga\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\talga\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\talga\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\talga\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\talga\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\talga\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\talga\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\talga\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\talga\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.11)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\talga\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\talga\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)
# Building wheels for collected packages: tensorflow-gpu
#   Building wheel for tensorflow-gpu (setup.py): started
#   Building wheel for tensorflow-gpu (setup.py): finished with status 'error'
#   Running setup.py clean for tensorflow-gpu
# Failed to build tensorflow-gpu
# Installing collected packages: tensorflow-gpu, opencv-python-headless, qudida, albumentations
#   Running setup.py install for tensorflow-gpu: started
#   Running setup.py install for tensorflow-gpu: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [18 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\talga\AppData\Local\Temp\pip-install-w1vnfpa2\tensorflow-gpu_1c938c2c644243379478c621ac558eaa\setup.py", line 37, in <module>
#       raise Exception(TF_REMOVAL_WARNING)
#   Exception:
#
#   =========================================================
#   The "tensorflow-gpu" package has been removed!
#
#   Please install "tensorflow" instead.
#
#   Other than the name, the two packages have been identical
#   since TensorFlow 2.1, or roughly since Sep 2019. For more
#   information, see: pypi.org/project/tensorflow-gpu
#   =========================================================
#
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tensorflow-gpu
#   error: subprocess-exited-with-error
#
#   Running setup.py install for tensorflow-gpu did not run successfully.
#   exit code: 1
#
#   [18 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\talga\AppData\Local\Temp\pip-install-w1vnfpa2\tensorflow-gpu_1c938c2c644243379478c621ac558eaa\setup.py", line 37, in <module>
#       raise Exception(TF_REMOVAL_WARNING)
#   Exception:
#
#   =========================================================
#   The "tensorflow-gpu" package has been removed!
#
#   Please install "tensorflow" instead.
#
#   Other than the name, the two packages have been identical
#   since TensorFlow 2.1, or roughly since Sep 2019. For more
#   information, see: pypi.org/project/tensorflow-gpu
#   =========================================================
#
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# tensorflow-gpu
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %% [markdown]
# # 2. Collect Images

# %%
import os
import time
import uuid
import cv2

# %%
IMAGES_PATH = 'data'
number_images = 80

# %%
cap = cv2.VideoCapture(0)
for imgnum in range(number_images):
    print('Collecting image {}'.format(imgnum))
    ret, frame = cap.read()
    imgname = os.path.join(IMAGES_PATH,f'{str(uuid.uuid1())}.jpg')
    cv2.imwrite(imgname, frame)
    cv2.imshow('frame', frame)
    time.sleep(0.5)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting image 10
# Collecting image 11
# Collecting image 12
# Collecting image 13
# Collecting image 14
# Collecting image 15
# Collecting image 16
# Collecting image 17
# Collecting image 18
# Collecting image 19
# Collecting image 20
# Collecting image 21
# Collecting image 22
# Collecting image 23
# Collecting image 24
# Collecting image 25
# Collecting image 26
# Collecting image 27
# Collecting image 28
# Collecting image 29
# Collecting image 30
# Collecting image 31
# Collecting image 32
# Collecting image 33
# Collecting image 34
# Collecting image 35
# Collecting image 36
# Collecting image 37
# Collecting image 38
# Collecting image 39
# Collecting image 40
# Collecting image 41
# Collecting image 42
# Collecting image 43
# Collecting image 44
# Collecting image 45
# Collecting image 46
# Collecting image 47
# Collecting image 48
# Collecting image 49
# Collecting image 50
# Collecting image 51
# Collecting image 52
# Collecting image 53
# Collecting image 54
# Collecting image 55
# Collecting image 56
# Collecting image 57
# Collecting image 58
# Collecting image 59
# Collecting image 60
# Collecting image 61
# Collecting image 62
# Collecting image 63
# Collecting image 64
# Collecting image 65
# Collecting image 66
# Collecting image 67
# Collecting image 68
# Collecting image 69
# Collecting image 70
# Collecting image 71
# Collecting image 72
# Collecting image 73
# Collecting image 74
# Collecting image 75
# Collecting image 76
# Collecting image 77
# Collecting image 78
# Collecting image 79

# %% [markdown]
# # 3. Create Dataset

# %%
import tensorflow as tf
import cv2
import json
import numpy as np
from matplotlib import pyplot as plt

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
def load_image(x): 
    byte_img = tf.io.read_file(x)
    img = tf.io.decode_jpeg(byte_img)
    return img

# %% [markdown]
# # 4. Move Matching Labels AFTER Annotation with Labelme

# %%
for folder in ['train','test','val']:
    for file in os.listdir(os.path.join('aug_data', folder, 'images')):
        
        filename = file.split('.')[0]+'.json'
        existing_filepath = os.path.join('aug_data','labels', filename)
        if os.path.exists(existing_filepath): 
            new_filepath = os.path.join('aug_data',folder,'labels',filename)
            os.replace(existing_filepath, new_filepath)

# %% [markdown]
# # 5. Image Augmentation

# %%
import albumentations as alb

# %%
augmentor = alb.Compose([alb.RandomCrop(width=450, height=450), 
                         alb.HorizontalFlip(p=0.5), 
                         alb.RandomBrightnessContrast(p=0.2),
                         alb.RandomGamma(p=0.2), 
                         alb.RGBShift(p=0.2), 
                         alb.VerticalFlip(p=0.5)], 
                        keypoint_params=alb.KeypointParams(format='xy', label_fields=['class_labels']))

# %%
for partition in ['train', 'test', 'val']: 
    for image in os.listdir(os.path.join('aug_data', partition, 'images')):
        img = cv2.imread(os.path.join('aug_data', partition, 'images', image))

        classes = [0,0]
        coords = [0,0,0.00001,0.00001]
        label_path = os.path.join('aug_data', partition, 'labels', f'{image.split(".")[0]}.json')
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                label = json.load(f)
    
            if label['shapes'][0]['label']=='LeftEye': 
                classes[0] = 1
                coords[0] = np.squeeze(label['shapes'][0]['points'])[0]
                coords[1] = np.squeeze(label['shapes'][0]['points'])[1]

            if label['shapes'][0]['label']=='RightEye':
                classes[1] = 1
                coords[2] = np.squeeze(label['shapes'][0]['points'])[0]
                coords[3] = np.squeeze(label['shapes'][0]['points'])[1]

            if len(label['shapes']) > 1:     
                if label['shapes'][1]['label'] =='LeftEye': 
                    classes[0] = 1 
                    coords[0] = np.squeeze(label['shapes'][1]['points'])[0]
                    coords[1] = np.squeeze(label['shapes'][1]['points'])[1]

                if label['shapes'][1]['label'] =='RightEye': 
                    classes[1] = 1
                    coords[2] = np.squeeze(label['shapes'][1]['points'])[0]
                    coords[3] = np.squeeze(label['shapes'][1]['points'])[1]
            
            np.divide(coords, [640,480,640,480])
                
        try: 
            for x in range(120):
                keypoints = [(coords[:2]), (coords[2:])]
                augmented = augmentor(image=img, keypoints=keypoints, class_labels=['LeftEye','RightEye'])
                cv2.imwrite(os.path.join('aug_data', partition, 'images', f'{image.split(".")[0]}.{x}.jpg'), augmented['image'])

                annotation = {}
                annotation['image'] = image
                annotation['class'] = [0,0]
                annotation['keypoints'] = [0,0,0,0]

                if os.path.exists(label_path):
                    if len(augmented['keypoints']) > 0: 
                        for idx, cl in enumerate(augmented['class_labels']):
                            if cl == 'LeftEye': 
                                annotation['class'][0] = 1 
                                annotation['keypoints'][0] = augmented['keypoints'][idx][0]
                                annotation['keypoints'][1] = augmented['keypoints'][idx][1]
                            if cl == 'RightEye': 
                                annotation['class'][1] = 1 
                                annotation['keypoints'][2] = augmented['keypoints'][idx][0]
                                annotation['keypoints'][3] = augmented['keypoints'][idx][1]
                                
                annotation['keypoints'] = list(np.divide(annotation['keypoints'], [450,450,450,450]))


                with open(os.path.join('aug_data', partition, 'labels', f'{image.split(".")[0]}.{x}.json'), 'w') as f:
                    json.dump(annotation, f)

        except Exception as e:
            print(e)
